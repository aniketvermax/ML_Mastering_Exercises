# %%
import pandas as pd

# %%
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
df.shape
# Out:
# (20, 3)

# %%
df.isna().sum()
# Out:
# Mileage          0
# Age(yrs)         0
# Sell Price($)    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.scatter(df['Mileage'], df['Sell Price($)'])

# %%
plt.xlabel('Age(yrs)')
plt.ylabel('Sell Price($)')
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])

# %% [markdown]
# Clearly it can be seen that they(Mileage and Age) have a linear replationship with Sell Price($)

# %%
x = df[['Mileage', 'Age(yrs)']]
y = df[['Sell Price($)']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([[20668.52722622],
#        [16762.33242213],
#        [25160.18381011],
#        [27209.30003936],
#        [37903.32633702],
#        [14729.61531335]])

# %%
y_test
# Out:
#     Sell Price($)
# 7           19300
# 10          18700
# 5           26750
# 6           32000
# 3           40000
# 18          12800

# %%
model.score(x_test,y_test)
# Out:
# 0.921242248377633
